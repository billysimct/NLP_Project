# %%
import pandas as pd
# read file from data
labelled_sentences = pd.read_excel('data/FOMC Labelled Sentences.xlsx')
statements = pd.read_excel('data/FOMC Statements 1997-2023.xlsx')

# %%
labelled_sentences.head()
# Out:
#    Unnamed: 0                                           Sentence Meeting Date
# 0           1  In addition, the Committee intends to purchase...   2010-12-14  \
# 1           2  _x000D_\n_x000D_\nThe Committee perceives that...   2003-09-16
# 2           3  _x000D_\n_x000D_\nIn these circumstances, alth...   2002-05-07
# 3           4  This assessment will take into account a wide ...   2015-01-28
# 4           5  \n_x000D_\n       Information received since t...   2010-11-03
#
#   Score
# 0    -1
# 1     0
# 2     0
# 3     0
# 4    -1

# %%
statements.head()
# Out:
#   Meeting Date                                         Unnamed: 1
# 0   1997-03-25  _x000D_\n_x000D_\n\tThe Federal Open Market Co...
# 1   1998-09-29  _x000D_\nThe Federal Open Market Committee dec...
# 2   1998-10-15  _x000D_\nThe Federal Reserve today announced t...
# 3   1998-11-17  _x000D_\nThe Federal Reserve today announced t...
# 4   1999-05-18  _x000D_\nThe Federal Reserve released the foll...

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc
from gensim.models import KeyedVectors

# %%
labelled_sentences_sample = labelled_sentences['Sentence'][0]
labelled_sentences_sample
# Out:
# 'In addition, the Committee intends to purchase $600 billion of longer-term Treasury securities by the end of the second quarter of 2011, a pace of about $75 billion per month.'

# %%
# Word Embeddings Augmenter
# substitution by word similarity

aug = naw.WordEmbsAug(
    model_type='word2vec', model_path='data/GoogleNews-vectors-negative300.bin',
    action="substitute")
augmented_text = aug.augment(labelled_sentences_sample)
print("Original:")
print(labelled_sentences_sample)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# In addition, the Committee intends to purchase $600 billion of longer-term Treasury securities by the end of the second quarter of 2011, a pace of about $75 billion per month.
# Augmented Text:
# ['In addition, same Committee aspires to borrow $ 600 #.##billion of indefinitely - term Treasury Collateralized_Debt_Obligations_CDOs by Rink_Rap end of the fourthplace quarter of 2011, a pace of Debunking_myths $ 75 ##.#bn per month.']

# %%
# Synonym Augmenter
# substitution by WordNet's synonym

aug = naw.SynonymAug(aug_src='wordnet')
augmented_text = aug.augment(labelled_sentences_sample)
print("Original:")
print(labelled_sentences_sample)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# In addition, the Committee intends to purchase $600 billion of longer-term Treasury securities by the end of the second quarter of 2011, a pace of about $75 billion per month.
# Augmented Text:
# ['In accession, the Committee intends to purchase $ 600 jillion of longer - condition Treasury securities by the close of the second quarter of 2011, a pace of astir $ 75 billion per month.']

# %%
# OCR Augmenter
# substitution by OCR error, e.g. 'l' vs 'i'

aug = nac.OcrAug()
augmented_text = aug.augment(labelled_sentences_sample, n=2)
print("Original:")
print(labelled_sentences_sample)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# In addition, the Committee intends to purchase $600 billion of longer-term Treasury securities by the end of the second quarter of 2011, a pace of about $75 billion per month.
# Augmented Text:
# ['1n addition, the Committee intends to pokcha8e $ 600 billion uf longer - tekm Treasury securities by the end of the second qoaktek of 2011, a pace of about $ 75 billion pek month.', 'In addition, the Committee intends to pokcha8e $ 600 6il1i0n uf l0n9er - term Trea8oky securities by the end uf the second quarter 0f 2011, a pace of a6oot $ 75 billion per month.']

# %%
# Random Word Augmenter
# swaps words randomly in sentence

aug = naw.RandomWordAug(action="swap")
augmented_text = aug.augment(labelled_sentences_sample)
print("Original:")
print(labelled_sentences_sample)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# In addition, the Committee intends to purchase $600 billion of longer-term Treasury securities by the end of the second quarter of 2011, a pace of about $75 billion per month.
# Augmented Text:
# ['In addition, the Committee to purchase intends $ 600 of billion longer - term Treasury securities the by end of the second quarter of 2011 a, of pace $ about per 75 month billion.']

# %%
# Function for augmenting the whole dataset by providing the augmenter

def augment_dataset(data, augmenter):
    augmented_data = []
    for sentence in data:
        augmented_data.append(augmenter.augment(sentence))
    return augmented_data

# %%
aug = naw.RandomWordAug(action="swap")
test = augment_dataset(labelled_sentences['Sentence'], aug)
test
# Out:
# [['Addition in, the intends Committee to purchase 600 $ billion longer of - term Treasury securities by end the second of the quarter of 2011 a, pace of $ about 75 billion month per.'],
#  ['_x000D_ _x000D_ perceives The Committee that the upside downside and risks to the of attainment sustainable growth for the next few quarters are roughly. equal'],
#  ['_x000D_ In _x000D_ these circumstances, although the stance of monetary policy currently is accommodative, the believes Committee that, the for foreseeable future, against the background of its long run goals of price stability and economic sustainable growth and of the information currently available, the risks are balanced respect with to the prospects for both goals. _x000D_ _x000D_ Voting for the FOMC monetary policy were action: Alan Greenspan, Chairman; William J. McDonough, Vice Chairman; Susan S. Bies; Roger W. Ferguson, Jr. ; Edward M. Gramlich; Jerry L Jordan. ; Robert D. McTeer, Jr. Mark; W. Olson; Anthony M. Santomero, and Gary H Stern..'],
#  ['This assessment will into take account a range wide of information, measures labor including of market conditions, indicators of inflation pressures and inflation, expectations and readings financial on international and developments.'],
#  ['Information _x000D_ received since the Federal Market Open Committee met in confirms September that pace the recovery of in output and employment slow to continues be.'],
#  ['Nonetheless the, Committee will changes respond to economic in as prospects to needed fulfill its obligation to_x000D_ price maintain stability.'],
#  ['For voting the policy monetary action Jerome were H. Powell, Chair; John C. Williams, Vice Chair; I Thomas. Barkin; Raphael W. Bostic; Michelle W. Lael Bowman; Brainard; Richard H. Clarida Mary C; . Daly; Charles. L Evans; Randal K. Quarles and; Christopher J. Waller.'],
#  ['Nonetheless, gains job have been in robust recent months, and the unemployment rate has remained low.'],
#  ['Moreover, the high resource level of utilization the has potential to sustain pressures. those'],
#  ['Progress with on vaccinations and strong policy, support indicators economic of activity and employment have continued to. strengthen'],
#  ['Appears output _x000D_ to be at growing a moderate despite the pace rise earlier in _x000D_ energy prices, and labor market conditions to continue gradually improve.'],
#  ['Voting the against was action Esther L George. , who was that concerned the continued high level monetary of accommodation the increased risks of future economic financial and and imbalances, over time, could cause increase in an long - term inflation expectations. _x000D_'],
#  ['Issued implementation Note 3 May, 2017'],
#  ['Consistent its with statutory mandate the Committee, seeks to maximum foster and employment price. stability'],
#  ['In light of the shortfall current inflation of from 2, percent the Committee carefully will monitor actual and expected toward progress its goal inflation.'],
#  ['This assessment will take into a account wide range of information including, of measures market labor, conditions of indicators inflation pressures and inflation expectations, and financial readings on and international developments.'],
#  ['Domestic but markets financial have recovered foreign and economic prospects since have improved the easing of monetary policy last fall.'],
#  ['In contrast the, probability, though minor of, an unwelcome in fall inflation exceeds that a of in rise from inflation its already low. level'],
#  ['The Committee will include purchases of agency commercial mortgage backed - securities in its agency mortgage - security purchases backed.'],
#  ['Harker patrick voted alternate as an member at meeting this.'],
#  ['Support of in goals these, the Committee decided to the target raise range for the federal funds rate to - 4 1 / 2 to 4 - 3 / 4 percent.'],
#  ['However, a sustained in moderation pressures inflation has yet be to convincingly demonstrated.'],
#  ['Voting for the policy monetary action H were Jerome. Chair Powell, ; John C. Williams, Vice Chair; Michelle W. Bowman; Lael Brainard; Bullard James Esther; L. George; ; Patrick Harker Loretta J. Mester and; Christopher J. Waller.'],
#  ['The _x000D_ Federal Committee decided Open Market today to keep its target the for funds federal rate unchanged at 1 3 4 / percent.'],
#  ['In determining the timing and size of future to adjustments the range target for the funds federal rate the, Committee will realized assess and expected economic to conditions relative maximum its employment objective its and symmetric 2 percent inflation. objective'],
#  ['Received _x000D_ Information the since Federal Open Market met Committee in suggests January that economic growth has moderated. somewhat'],
#  ['This will assessment take into wide account a of range information, measures including of market conditions labor, indicators of inflation and pressures inflation expectations, and readings on and financial developments international.'],
#  ['In determining how long to maintain a highly accommodative of stance policy monetary, the Committee also will consider information other, including additional measures labor market of indicators conditions, of pressures inflation and expectations inflation, and readings on financial developments.'],
#  ['Received information since Federal the Open Market Committee met in suggests January that has economic activity been expanding at a moderate pace the despite economic global and developments financial of recent months.'],
#  ['_x000D_ _x000D_ Although the necessary reallocation of resources to security enhance may restrain advances in productivity for a time, long the - term prospects for growth productivity and the economy remain favorable should and become once evident forces the unusual restraining demand abate. _x000D_ _x000D_ In taking the discount rate action, the Federal Reserve approved Board the request submitted by the Board of Directors of the Federal Reserve Bank of Richmond. _x000D_ 2001 Monetary policy Home | and News events Accessibility Last update: November 6, 2001'],
#  ['Recent information indicates the outlook that for economic activity further has weakened.'],
#  ['Data available suggest that household spending fixed and investment business, advanced while the in recovery the housing slowed somewhat sector in recent months.'],
#  ['Its based on current assessment, the judges Committee that it can patient be in to beginning the normalize stance of monetary policy.'],
#  ['_x000D_'],
#  ['Note implementation issued 14 December 2022,'],
#  ["Program this, which would gradually the reduce Federal Reserve ' securities s by holdings decreasing reinvestment of principal payments from securities those is, described in the accompanying to the addendum Committee ' Policy s Principles Normalization and Plans."],
#  ['Determining in how long to maintain this target, range the will Committee assess progress - - both and expected realized - - toward objectives its maximum of and percent employment 2 inflation.'],
#  ['Longer term - inflation have expectations stable remained.'],
#  ['Ongoing the public crisis health will heavily weigh on economic activity, employment, inflation and in the term near, and poses considerable risks the to economic over outlook the term medium.'],
#  ["Inflation has running been somewhat below the Committee s ' longer - objective run, from apart temporary that variations largely reflect energy fluctuations in prices."],
#  ['Information received the since Federal Market Open Committee met in indicates June that labor market the has continued to that strengthen and economic has activity been rising at a strong rate.'],
#  ['Voting against action the L were. Charles Evans and Neel Kashkari, who preferred at meeting this maintain to the existing target range for the federal rate funds.'],
#  ['Market - based of measures inflation remain compensation; low - survey based measures longer of - inflation expectations term are changed little.'],
#  ['Federal the Reserve is to committed using its full of range to tools the support U. S. economy in this challenging time, promoting thereby maximum its employment and price goals stability.'],
#  ['Activity the in housing sector has increased recent over months.'],
#  ['In addition the, Federal Reserve will to buy up $ 300 of Treasury billion securities autumn by.'],
#  ['Inflation _x000D_ longer and - term inflation remain expectations well contained. The _x000D_ Committee perceives the and upside downside risks to attainment the _x000D_ of sustainable both and growth stability price for the next few _x000D_ quarters be to roughly equal.'],
#  ['In increases the prices of and energy other commodities have up pushed in inflation months. recent'],
#  ['The will Committee monitor carefully actual and expected inflation developments to its relative symmetric inflation goal.'],
#  ['Recent are developments likely to result credit in tighter conditions for households businesses and and on to weigh economic, hiring activity, and inflation.'],
#  ['Risks the to economic outlook remain, including from variants new the of virus.'],
#  ["This policy, by keeping the Committee ' s holdings longer of - term securities at levels sizable, should help maintain accommodative financial conditions. _x000D_ _x000D_ To support continued progress toward maximum and employment stability, price the Committee today its reaffirmed that view the current 0 to / 1 percent 4 range target for the federal funds rate remains appropriate."],
#  ['Range a of labor recent indicators market, strong including job gains, to points additional some in decline of underutilization labor resources.'],
#  ['Accelerates this release action the of this information, currently available in Minutes the with lag a.'],
#  ['Inflation has risen largely, transitory factors reflecting.'],
#  ["The of experience last the several years has reinforced conviction the that inflation low is essential to the realizing economy ' s growth fullest potential."],
#  ['Federal the Reserve prepared is to modify these plans necessary if to financial stability support economic and growth.'],
#  ['Overall financial conditions have improved in recent months, in reflecting part policy to support measures economy the and flow the of credit to U. S. households and. businesses'],
#  ['The Committee as contemplates the future path the of target range the for federal funds rate, it will continue to monitor the incoming implications of information for the economic outlook and will act as appropriate to sustain expansion the, with a strong labor market inflation and near its symmetric 2 percent objective.'],
#  ['Media for inquiries please, email [email protected] call or - 452 202 2955 -.'],
#  ['With the 75 basis point decline in federal the funds rate since September, financial can reasonably conditions be expected to be consistent with fostering sustained economic expansion while keeping inflationary pressures subdued. _x000D_ _x000D_ In taking the discount rate action, Board the approved requests submitted by Boards the of of Directors the Reserve Federal Banks New of, York, Philadelphia and Dallas.'],
#  ['The judges Committee that reductions similar in the pace of net asset purchases will be likely appropriate each month but, it is prepared to adjust pace of the if purchases warranted by changes in economic the outlook.'],
#  ['Policy fiscal economic is restraining growth, although the of extent is restraint diminishing.'],
#  ['Inflation expected is to remain low in the near in term, part because of further the declines in energy prices, but to rise 2 to percent over the medium term as the transitory effects of declines energy in prices and import dissipate and the labor market strengthens further.'],
#  ['However, the judges Committee that some risks inflation, remain and will it continue monitor inflation to carefully developments.'],
#  [', currently unemployment the rate remains, elevated and of measures underlying inflation continue to be somewhat low, to relative levels Committee that the judges be to consistent, over the, longer run with its dual mandate.'],
#  ['Longer inflation - term expectations stable have remained. _x000D_ _x000D_ with Consistent its statutory, mandate the Committee to seeks foster maximum and employment price stability.'],
#  ['The Committee anticipates that it will be appropriate to raise the target range for the federal funds it rate when has seen some further improvement in the labor market and is reasonably confident that inflation will to move back 2 its percent objective over the medium term. _x000D_ _x000D_ Committee The is maintaining its existing policy of principal reinvesting payments from its holdings of agency debt and agency mortgage - backed securities in agency mortgage - securities backed and of over rolling maturing Treasury securities at auction.'],
#  ['Job gains been have strong in months recent, the rate and has unemployment stayed low.'],
#  ['The Committee monitor will carefully actual and expected inflation developments to relative its symmetric goal inflation.'],
#  ['In light of the improving economy, Mr. Hoenig was that a concerned continued high of monetary level accommodation would increase the risks of future economic and financial imbalances and, over, time would cause an increase in long - inflation term that could expectations destabilize the. _x000D_ economy'],
#  ['In how determining long to maintain this range target, the Committee assess will - progress both realized - and expected - - toward of its maximum objectives employment and 2 inflation percent.'],
#  ['With underlying inflation still to be expected relatively, low Committee the believes policy that can accommodation be removed at a pace that is to likely be measured.'],
#  ['Voting for the FOMC policy action monetary were: Ben S. Bernanke, Chairman; C William. Dudley, Chairman Vice; Elizabeth A. Duke; Charles. L Evans; Donald L Kohn. ; Jeffrey M. Lacker; Dennis P Lockhart. ; Daniel K Tarullo. ; Kevin M. ; Warsh and Janet L Yellen..'],
#  ['_x000D_ the Open Market Federal voted Committee today raise to its target for the federal rate funds 25 by basis points to 5 - 3 4 / percent.'],
#  ["Inflation has increased since this earlier year is but below still the Committee ' s 2 percent longer - run objective, reflecting partly earlier declines energy in and prices in prices of non energy -. imports"],
#  ['Still, about uncertainty inflation the outlook high remains.'],
#  ['Information recent that indicates economic remains activity weak.'],
#  ['Information received since Federal the Open Committee Market met in indicates June that the market labor continued has strengthen to and that economic activity has been rising moderately so far this year.'],
#  ['Committee the perceives the upside and downside to risks attainment the sustainable of both and price growth stability for the next few quarters to be roughly equal.'],
#  ['Received since information Federal the Open Market Committee met September in indicates that the labor market has to continued strengthen and economic activity that has been rising at strong a rate.'],
#  ['Household spending and business investment fixed have increasing been at solid rates in recent months, and the housing sector improved has; further however net, have exports been soft.'],
#  ['When the decides Committee to begin remove to policy accommodation, it will take a balanced approach consistent with its longer - run goals of employment maximum and inflation of 2 percent. _x000D_ _x000D_ for Voting the FOMC monetary policy action were: Ben S Bernanke. , Chairman William; C. Dudley, Vice; Chairman Elizabeth A. Duke; Charles L. Evans; Jerome H. Powell; Bloom Sarah Raskin; Eric S. Rosengren; C Jeremy. Stein; Daniel K. Tarullo; and Janet L. Yellen.'],
#  ['Committee the that judges some further policy yet firming may be needed to address inflation risks but emphasizes that the extent timing and such of any firming will depend importantly on evolution the the of economic as outlook implied by incoming information.'],
#  ['In determining the and timing of size adjustments future to the target for range the federal funds rate, the assess Committee will realized and expected economic conditions relative to its maximum employment its objective symmetric and 2 percent inflation. objective'],
#  ['Although recent data economic have uneven been, the in expansion economic activity appears solid.'],
#  ['Stance the monetary of policy, remains accommodative thereby supporting some further strengthening in labor conditions market and sustained return a 2 to percent inflation.'],
#  ['In light of the current shortfall of inflation from 2 percent, the Committee carefully monitor actual will and progress expected inflation toward its goal.'],
#  [', moreover there significant are downside to risks the economic outlook including, in strains global markets financial.'],
#  ['Determining in the timing and size of future adjustments to the target range for the federal funds rate, the will Committee assess and realized expected economic relative conditions to objectives its of maximum 2 employment and inflation percent.'],
#  ['A in action related, Board the of approved Governors basis a 50 point reduction in discount rate the to 3 - 1 / 2. percent'],
#  ['_x000D_ Voting _x000D_ for the FOMC monetary action policy were Alan, Greenspan Chairman; William J. McDonough, Chairman Vice; Ben S. Bernanke, S Susan. Bies; J. Broaddus Alfred, Jr. ; Roger W Ferguson. , Jr. ; Edward M. Gramlich; Jack Guynn; Donald L. Kohn Michael; H. Moskow; Mark W Olson. , and Robert T. . Parry'],
#  ["The Committee ' s assessments take will into account a range wide of information, readings including on health public, market labor, conditions pressures inflation and inflation expectations, and financial international and developments."],
#  ['Information received since the Federal Market Open Committee met in indicates March that the labor market continued has to strengthen even as in growth economic slowed activity.'],
#  ['The Committee currently anticipates that, even after employment and inflation are mandate near - consistent levels, economic conditions may, for some time, warrant keeping the target federal funds rate below levels the Committee views as normal in the longer run. _x000D_ _x000D_ Voting for the FOMC monetary policy action were: Janet L. Yellen, Chair; William C. Dudley, Vice Chairman; Lael Brainard Charles; L. Evans Stanley; Fischer; Jeffrey M. Lacker; Dennis. Lockhart P; Jerome H Powell. ; Daniel K. Tarullo; and C John. Williams. _x000D_'],
#  ['A action in related, the Board of Governors approved a unanimously 25 - basis - point in decrease discount the rate 4 - to 3 / 4 percent.'],
#  ['The sectors most adversely affected the by pandemic have in improved recent months but continue be to affected by COVID - 19.'],
#  ['In beginning February, the Committee will add to its of holdings agency mortgage - securities backed a at pace of $ 30 billion per month rather than $ 35 billion per month, and add will to holdings its of longer - term securities Treasury at a pace of $ 35 billion per month rather than $ 40 per billion month.'],
#  ['_x000D_ _x000D_ pressures With labor on product and easing markets, inflation is expected to remain contained.'],
#  ['Voting for FOMC the monetary policy action were: Ben S. Bernanke, Chairman; . Timothy Geithner F, Vice Chairman; Charles L. Evans; Donald L. Kohn; Randall S. Kroszner; Frederic S. ; William Mishkin Poole; Eric S Rosengren. and; Kevin M. Warsh.'],
#  ['Employment was payroll little changed in February, but job gains have been solid, on average in, recent months, and unemployment the rate has remained. low'],
#  ['Against voting Richard were W. and Charles Fisher I. , Plosser who preferred less action aggressive at this. meeting'],
#  ['A on 12 - month basis, both overall inflation and for inflation items food other than remain and near energy 2. percent'],
#  ["Russia ' war s against Ukraine causing is tremendous human economic and and hardship contributing to is elevated uncertainty global."],
#  ['Weaker demand and earlier in declines prices oil have been holding consumer down price inflation.'],
#  ['The will maintain Committee the target range for the federal funds rate at to 0 1 / 4 and percent continues to anticipate that conditions economic are likely warrant to exceptionally low levels the of federal funds for rate period an extended.'],
#  ['With inflation underlying expected relatively to be _x000D_ low, the Committee that believes policy can accommodation be removed at a _x000D_ pace is that likely be to. measured'],
#  ['Balance, on a range of labor market indicators suggests that of underutilization resources labor diminished somewhat.'],
#  ['Voting for the monetary policy action were Jerome H. Powell, ; Chair John C. Williams, Vice Chair Michael; S. Barr; Michelle W. ; Lael Bowman Brainard James; Bullard; M Susan. Collins; D Lisa. Cook; Esther L. George; Philip N. Jefferson; Loretta J. Mester; and J Christopher. Waller.'],
#  ['Voting for the monetary action policy Jerome were. H Powell, ; Chair John C. Williams, Chair Vice; Michelle W. Bowman; Lael Brainard; James; Bullard H Richard. Clarida; Charles L Evans. ; Esther L. George Randal; . K Quarles; and Eric S. Rosengren.'],
#  ['The Committee intends to, purchase by the end of June 2012, $ billion of 400 Treasury securities with remaining maturities 6 of years to 30 years and to sell an equal amount Treasury of with securities remaining of maturities 3 years less or.'],
#  ['Inflation been has subdued, although the prices of key commodities some have increased recently.'],
#  ["The Committee directs the Desk to continue over rolling at all auction principal payments from the Federal Reserve ' s holdings Treasury of and securities to continue reinvesting principal all payments from the Federal Reserve ' s holdings of agency debt and agency mortgage - received backed securities during calendar each month."],
#  ['This action accelerates release the of information this, available currently the in Minutes a lag with.'],
#  ['Spending household to appears at be expanding a moderate rate though, it constrained by remains a weak labor market, growth modest income, housing lower wealth, and tight credit.'],
#  ['Voting against was Charles I. Plosser who objected to the indicating guidance that it likely be will appropriate to maintain the current target range the for federal for funds rate " a considerable time after the asset purchase ends program, " because such language is time dependent and does not the reflect economic progress considerable that been has made toward the Committee \' s goals. _x000D_'],
#  ['Arrangement with the the of Bank Canada would support of drawings to up $ 30 billion, was the as case previously.'],
#  ['- market measures based of compensation inflation remain low; survey - measures based of longer - term inflation expectations little are changed, balance on, in recent months.'],
#  ['The Committee is maintaining its existing policy of reinvesting principal payments its from of holdings debt agency and mortgage agency - backed securities in agency mortgage - backed securities and of over rolling maturing Treasury securities at, auction and it anticipates so doing normalization until of the level of federal the funds rate is well way under.'],
#  ['- near term to the risks economic outlook diminished have.'],
#  ['In a related action, Board the Governors of approved a basis 25 point in the reduction rate discount to 1 - 1 4 / percent.'],
#  ['Committee the seeks achieve to maximum employment inflation and at the rate of percent over 2 longer the run.'],
#  ['Tight credit conditions, ongoing the housing contraction and, slowing some export in are likely to growth on weigh growth economic over the next few quarters.'],
#  ['The arrangements with the Bank of England, the ECB, and the Swiss National will Bank these provide central banks with the capacity conduct to tenders of U. . S dollars in their markets local at fixed for rates full allotment, similar to that arrangements had been in previously place.'],
#  ['This change the in forward guidance does not that indicate the Committee has decided on the timing of the initial increase the in target range. _x000D_ _x000D_ The Committee is maintaining its existing policy of reinvesting principal payments from its holdings of agency debt agency and mortgage - backed securities in agency mortgage - and backed securities of rolling over maturing Treasury securities at auction.'],
#  ['Voting the for FOMC monetary policy action were Ben: S Bernanke. ,; Chairman Timothy F. Geithner, Chairman Vice; Susan. S Bies; Jack Guynn; L Donald. Kohn; Randall S. Kroszner; Jeffrey M. Lacker; Mark W Olson. ; Sandra; Pianalto M Kevin. Warsh; and Janet L. Yellen.'],
#  ['In view and of realized market expected labor conditions inflation and, the Committee to decided the raise target range for federal the funds rate to 2 2 to - 1 / 4. percent'],
#  ['Markets financial remain under considerable stress, and credit tight and conditions the deepening housing contraction are likely weigh to economic growth over on the next few quarters.'],
#  ['Future policy adjustments will depend on evolution the of outlook for the both inflation and economic growth, as incoming implied by. information'],
#  ['However the, actual path of the federal funds rate will on depend economic the outlook as by informed incoming. data'],
#  ['In determining the timing and size of adjustments to future the target range for the funds federal rate, the Committee assess will and realized expected economic relative conditions its to of objectives employment maximum and percent 2 inflation.'],
#  ['The Committee will continue assess the to effects of financial other and developments on economic and prospects act will needed as to foster price stability and economic sustainable growth.'],
#  ['Voting against action the was Esther L. George, was who concerned that the continued high level of monetary accommodation increased the of economic risks future and imbalances financial and over, time, could cause an increase long in - inflation term expectations _x000D_.'],
#  ['In the erosion and current prospective profitability, combination in with uncertainty considerable the about business, outlook seems to likely hold down capital going spending forward.'],
#  ['_x000D_ _x000D_ Although the necessary reallocation resources of to enhance security may restrain advances in for productivity a time, the - long term prospects for growth productivity and the economy remain and favorable should become evident once the unusual forces restraining demand abate. _x000D_ _x000D_ In taking discount the rate action, the Federal Reserve Board approved the request submitted by the Board Directors of of the Federal Reserve Bank of Richmond. _x000D_ 2001 policy Monetary Home | News and events Accessibility Last update: November 6, 2001'],
#  ['Household is spending moderately rising and business is fixed investment advancing while, the in recovery housing the sector remains slow.'],
#  ['The to continues Committee the see to risks outlook the for economic activity and the labor market as balanced nearly.'],
#  ['Support in of these goals, the Committee decided to maintain the target the range for federal funds rate at 2 1 - / 4 to 2 - 1 / 2 percent.'],
#  ["The Committee now anticipates, based its on assessment of these factors, that likely it be will to appropriate the maintain current target range for the funds federal rate past well the that time the unemployment rate declines below 6 - 1 / 2 percent, especially if projected inflation continues run to below the Committee ' s 2 percent longer - goal run."],
#  ["Policy this, keeping the by ' Committee holdings s of longer - term at sizable securities, levels should help maintain accommodative financial conditions."],
#  ['Increases recent the in the prices and of energy other commodities are currently putting upward on pressure inflation.'],
#  ['Statement Regarding Transactions in Agency Mortgage - Securities Backed Treasury and Securities'],
#  ['Overall conditions financial remain accommodative, in part reflecting to policy measures support the and economy flow the of credit U to. S. households and. businesses'],
#  ['The Committee to continues anticipate that economic are conditions likely exceptionally to warrant levels low of federal the funds for rate time some.'],
#  ["Growth in household spending declined households; ' rose real, incomes strongly earlier partly reflecting declines energy in prices, consumer and sentiment remains high."],
#  ['Federal Reserve the is committed to using full its of range to tools support the U. . S in economy this time challenging thereby, promoting its maximum employment and price stability. goals'],
#  ['Particular in, the Committee decided today to keep the target range for the federal funds rate at to 0 1 / 4 percent and currently anticipates that economic conditions - - including low rates of resource utilization and a subdued outlook for over inflation the medium run - - are likely to warrant exceptionally low levels the for federal funds at rate least through late 2014. _x000D_ _x000D_ The Committee also decided to through continue the end of the year its program to extend the average maturity of its holdings of securities as announced in June, and it is maintaining its existing policy of reinvesting payments principal from its holdings of agency debt and agency mortgage - securities backed agency in mortgage - backed securities.'],
#  ['_x000D_ Information since received Federal the Open Market Committee in met March suggests that growth economic slowed during winter the in months part, transitory reflecting factors.'],
#  ['The continues to Committee closely monitor inflation indicators and global economic financial and developments.'],
#  ['Inflation well with above 2 percent and strong a labor, market the Committee it expects will be soon to appropriate the raise range target for federal the funds rate.'],
#  ['In any, event the will Committee respond changes to prospects in as economic needed to support the of attainment its objectives.'],
#  ['Supply and imbalances related demand to the pandemic and the the reopening of have economy to continued contribute to elevated levels of inflation.'],
#  ['In light of toward the cumulative progress maximum and employment the in improvement the outlook for market labor conditions the, decided to Committee make a further measured in reduction the pace of its asset purchases.'],
#  ['The Committee expects that, with policy accommodation appropriate, activity will economic at expand a moderate pace, labor with market and indicators inflation moving toward the levels Committee judges with consistent its mandate dual.'],
#  ['Related hurricane - and disruptions have rebuilding affected economic activity, and employment, inflation in months recent but have not materially altered the outlook for the national economy.'],
#  ['In these circumstances, the Federal will Reserve all employ available to tools economic promote recovery preserve and price to stability.'],
#  ['In addition, the Committee directs the Desk to conduct overnight reverse repurchase operations (and reverse repurchase operations with maturities of more one than day when necessary accommodate to weekend holiday, , or similar trading conventions) at an offering rate of 0. percent 00, in amounts limited only by the value of Treasury securities outright held in the System Account Open Market that are available such for and operations by a per counterparty - limit of $ 30 billion per day.'],
#  ['The Committee continues monitor to inflation closely developments. _x000D_ To _x000D_ support progress continued maximum toward employment price and stability, the Committee today reaffirmed view its that the current 0 to 1 / 4 percent target for range federal the funds rate appropriate remains.'],
#  ['Sees the Committee the to risks the outlook for the economy the and labor having market as become nearly more balanced.'],
#  ['In addition, the Committee continue will reducing its holdings Treasury securities and of agency debt and mortgage agency - backed securities, as described its in announced previously. plans'],
#  ['Assessment this will into take account a range wide information of, measures including labor of market conditions, indicators of pressures inflation and expectations inflation, and on readings and financial international developments.'],
#  ['Job gains been strong have in recent months and, unemployment the rate has stayed low.'],
#  ['Although rate the unemployment little is changed recent in, months job have gains been solid.'],
#  ['A however, sustained moderation inflation in pressures yet has to be demonstrated convincingly.'],
#  ['Lending bank has to continued in contract recent months.'],
#  ['In determining timing the size of and future adjustments to the target range for the funds federal rate, the Committee will assess and expected realized economic conditions maximum relative to its employment objective and its symmetric 2 inflation percent objective.'],
#  ['Committee is the its maintaining existing of policy reinvesting principal payments from its holdings of agency debt agency mortgage and - securities backed in agency mortgage - securities backed and rolling of over Treasury maturing securities at auction.'],
#  ['The Committee that expects conditions economic will evolve in a manner will that warrant gradual increases in federal the funds rate; federal the funds rate is likely to remain, for some time, below are levels that to expected prevail in the longer run.'],
#  ['The erosion current in prospective and profitability, in combination with considerable uncertainty business the about outlook, seems likely to down capital hold spending going forward.'],
#  ['Inflation _x000D_ and longer - term inflation expectations remain well contained. Committee _x000D_ The perceives the upside and downside risks to the attainment _x000D_ of growth sustainable both and price stability for next the quarters few to _x000D_ roughly be. equal'],
#  ['In action taking this, the Board approved the submitted requests by the Boards of Directors the of Federal Banks Reserve of Boston, New York, , Philadelphia Cleveland, Richmond, Atlanta, Chicago, St. Louis Minneapolis, , Kansas City, Dallas, and San Francisco. _x000D_ _x000D_ _x000D_ _x000D_ 2005 Monetary policy | Home News and _x000D_ events Accessibility Last update: 9 August, 2005'],
#  ['Economic activity and employment have continued recover to remain but well below levels their at beginning the of the. year'],
#  ['Recent data economic although have been uneven, the expansion in economic activity appears. solid'],
#  ['In determining the extent of future in increases the target range the, Committee take will into account the cumulative of monetary tightening policy the, which lags with monetary policy economic affects activity and inflation, and economic and developments financial.'],
#  ['Possibility the this that excess could continue for some time and the for potential weakness in global economic suggest substantial conditions risks that and demand could remain production. soft'],
#  ['In the determining timing and size of adjustments future to target the range for the funds federal rate, the will Committee assess realized and expected conditions economic relative its to objectives of employment maximum and 2 percent inflation.'],
#  ['Subdued the of behavior those expectations so has far contributed importantly to an maintaining conducive environment maximum to growth sustainable.'],
#  ['Signs recent point to firming in a spending, improved markedly financial conditions, and and labor product markets that stabilizing are.'],
#  ['In determining how to long maintain this target range, the will Committee assess progress - - both and realized expected - - toward its of objectives maximum employment and percent 2. inflation'],
#  ['Job gains have solid been recent in, months and unemployment the rate declined has. substantially'],
#  ['Voting against the policy action was Thomas M. Hoenig who, believed that continuing the to express expectation of exceptionally low levels of the funds federal rate an for extended was period no warranted longer because it could lead to the buildup of financial imbalances and increase to risks longer - macroeconomic and run financial stability. _x000D_'],
#  ['Committee expects the inflation to moderate coming quarters in, a reflecting leveling projected - out of and energy other commodity and prices an easing of pressures resource on. utilization'],
#  ['Ongoing the public health crisis continues to on weigh economic activity, , employment and, inflation and poses considerable risks the to economic. outlook'],
#  ['In particular, Committee decided the today to keep the target range for the federal funds rate at 0 to 1 4 / percent and currently anticipates that economic conditions - - including low rates of resource utilization and a outlook subdued inflation for over the medium run - - are likely to warrant exceptionally levels low for the funds federal rate at least through late 2014. _x000D_ _x000D_ Committee The also decided to continue its program to extend the average maturity of its holdings of securities as announced September in.'],
#  ['_x000D_ _x000D_ The Committee believes that, even after action this the, of stance policy monetary remains accommodative, and coupled robust with underlying growth in productivity, providing is support ongoing to economic activity.'],
#  ['Although unemployment the rate little is changed in recent gains months, job have been. solid'],
#  ["' russia s against war Ukraine is causing tremendous human economic hardship. and"],
#  ['Amid progress this strong and policy support, of indicators economic activity employment and have strengthened.'],
#  ['The will Committee continue its purchases of Treasury and agency mortgage - backed, securities employ and its other policy tools appropriate as, until the outlook the for labor market improved has substantially in a context price of. stability'],
#  ['Inflation picked has up recent in months mainly, reflecting prices for higher some imported commodities and goods, as well as the supply recent chain. disruptions'],
#  ['In support of goals these, Committee the decided to raise the for target range the federal rate funds 4 to - / 1 4 4 to - / 1 percent 2.'],
#  ['The Committee perceives that, with appropriate policy monetary action, upside the and risks downside attainment to the of both growth sustainable and stability price should kept be roughly equal.'],
#  ['Growth appears economic have to moderate during been the first this half of year, the despite ongoing adjustment in the housing sector.'],
#  ['Federal announces Reserve new extensive measures to the support economy'],
#  ['Although economic activity is likely to remain weak for a time the, Committee anticipates that policy actions to stabilize financial markets and institutions, fiscal and monetary stimulus, and market forces will contribute to a strengthening of economic growth and a gradual return higher to levels of resource utilization in a context of stability price. _x000D_ _x000D_ With substantial resource slack likely to continue to dampen cost pressures and with longer - term inflation expectations stable, the expects Committee that inflation will remain subdued for some time. _x000D_ _x000D_ The will Committee maintain the target range for the federal funds rate at to 0 1 / 4 percent and continues to anticipate that economic conditions, including low rates of resource utilization, subdued trends inflation, and stable inflation expectations, are to likely warrant exceptionally low of levels the federal funds rate an for extended period.'],
#  ["The committee to expects implementing begin its balance normalization sheet relatively program soon, provided that the economy evolves as broadly anticipated; this program is described in the 2017 June Addendum the to Committee ' s Policy Principles Normalization and Plans."],
#  ['The Committee expects that, with gradual adjustments in the stance monetary of policy, economic activity will at expand moderate a pace and labor market will conditions strengthen somewhat further.'],
#  ['Spending household appears to be moderately rising and business investment is fixed advancing, the while recovery in housing sector the slow remains.'],
#  ["Light in of the substantial further progress the economy has made toward the Committee ' s since goals last December, the Committee decided begin to the reducing monthly pace of its purchases net asset by $ 10 billion for securities Treasury and $ 5 billion agency for mortgage - backed securities."],
#  ['In addition, over coming months the Federal will Reserve increase holdings its of Treasury and securities agency mortgage - backed at securities least at the pace current to sustain market smooth and functioning help foster accommodative financial, conditions thereby supporting the of flow credit households to and businesses.']]
